# %% [markdown]
# # Import und Installation

# %%
# %run ../src/install/install_MaiOmni.py

# %% [markdown]
# # Ordner strucktur

# %%
# %run ../src/install/install_folder_index.py
# Out:
# 2026-07-07 01:20:25,499 - [INFO] - --- Stochastische Projekt-Initialisierung gestartet ---
# 2026-07-07 01:20:25,500 - [INFO] - Bestätigtes Hauptverzeichnis (Root): /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo
# 2026-07-07 01:20:25,501 - [INFO] - [OK - GESCHÜTZT] Begriff 'root' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo
# 2026-07-07 01:20:25,501 - [INFO] - [OK - GESCHÜTZT] Begriff 'config' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo/config
# 2026-07-07 01:20:25,502 - [INFO] - [ERSTELLT] Neuer stochastischer Begriff 'data' --> Pfad: /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo/data
# 2026-07-07 01:20:25,503 - [INFO] - [ERSTELLT] Neuer stochastischer Begriff 'knowledge' --> Pfad: /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo/knowledge
# 2026-07-07 01:20:25,504 - [INFO] - [OK - GESCHÜTZT] Begriff 'logs' bereits aktiv --> Pfad: /Users/cristallagus/Desktop/IHK_Prüfung/IHK_Repo/logs
# ...
